# %%
import os
import cv2
import matplotlib.pyplot as plt

# %%
BASE_DIR = r"C:\Users\Adith Sree Jey\OneDrive\Desktop\Project\New\DeepVessel_Net-main"

train_img_dir = os.path.join(BASE_DIR, "Data", "train", "image")
train_mask_dir = os.path.join(BASE_DIR, "Data", "train", "mask")

print("Image folder path:", train_img_dir)
print("Mask folder path:", train_mask_dir)

sample_img_name = os.listdir(train_img_dir)[0]
print("Sample image name:", sample_img_name)
# Out:
# Image folder path: C:\Users\Adith Sree Jey\OneDrive\Desktop\Project\New\DeepVessel_Net-main\Data\train\image
# Mask folder path: C:\Users\Adith Sree Jey\OneDrive\Desktop\Project\New\DeepVessel_Net-main\Data\train\mask
# Sample image name: 0.png

# %%
import cv2
import matplotlib.pyplot as plt

img_path = os.path.join(train_img_dir, sample_img_name)
mask_path = os.path.join(train_mask_dir, sample_img_name)  # matching mask name

img = cv2.imread(img_path)
mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(img_rgb)
plt.title("Retina Image")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(mask, cmap="gray")
plt.title("Vessel Mask")
plt.axis("off")
plt.show()

# %%
import torch

if torch.cuda.is_available():
    print("✅ GPU is available:", torch.cuda.get_device_name(0))
else:
    print("❌ GPU not available, using CPU")
# Out:
# ❌ GPU not available, using CPU
